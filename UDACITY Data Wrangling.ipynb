# %%
import pandas as pd
import numpy as np
import requests as rq
import json as js

# %%
# !pip install tweepy

# %%
import tweepy

# %%
consumer_key = 'J2TX0JearjjYeXleadTUhPyCQ'
consumer_secret = 'GKfGOYigtkkIqCbNBZrLLv9bWp9p4fSdArYNYx5LnG3jkOBJJu'
access_token = '75370479-OzdksulPQv3A23A3Ax93a8pHaWHeQM4MPLNChaIJJ'
access_secret = 'ez6hWnuwNE5FsNBeofE208mEbPfbvvm7JG7zLAlcLCqNG'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

#api = tweepy.API(auth)
api = tweepy.API(auth_handler=auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
from __future__ import print_function
import getopt
import logging
import os
import sys

# %%
import requests

# %%
r = requests.get('https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv', auth=('user', 'pass'))

# %%
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'text/tab-separated-values; charset=utf-8'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
import csv
df=pd.DataFrame()
wrapper = csv.reader(r.text.strip().split('\n'))
list_of_tuples = list(map(tuple, wrapper))

# %%
list_of_tuples[0]
# Out:
# ('tweet_id\tjpg_url\timg_num\tp1\tp1_conf\tp1_dog\tp2\tp2_conf\tp2_dog\tp3\tp3_conf\tp3_dog',)

# %%
df = pd.DataFrame(list(list_of_tuples))

# %%
df
# Out:
#                                                       0
# 0     tweet_id\tjpg_url\timg_num\tp1\tp1_conf\tp1_do...
# 1     666020888022790149\thttps://pbs.twimg.com/medi...
# 2     666029285002620928\thttps://pbs.twimg.com/medi...
# 3     666033412701032449\thttps://pbs.twimg.com/medi...
# 4     666044226329800704\thttps://pbs.twimg.com/medi...
# ...                                                 ...
# 2071  891327558926688256\thttps://pbs.twimg.com/medi...
# 2072  891689557279858688\thttps://pbs.twimg.com/medi...
# 2073  891815181378084864\thttps://pbs.twimg.com/medi...
# 2074  892177421306343426\thttps://pbs.twimg.com/medi...
# 2075  892420643555336193\thttps://pbs.twimg.com/medi...
#
# [2076 rows x 1 columns]

# %%
df = df[0].str.split('\t',expand=True)

# %%
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header

# %%
df.head(2)
# Out:
# 0            tweet_id                                          jpg_url  \
# 1  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 2  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
#
# 0 img_num                      p1   p1_conf p1_dog                  p2  \
# 1       1  Welsh_springer_spaniel  0.465074   True              collie
# 2       1                 redbone  0.506826   True  miniature_pinscher
#
# 0              p2_conf p2_dog                   p3    p3_conf p3_dog
# 1             0.156665   True    Shetland_sheepdog  0.0614285   True
# 2  0.07419169999999999   True  Rhodesian_ridgeback    0.07201   True

# %%
tweet = api.get_status(666020888022790149)
print(tweet.text)
# Out:
# Here we have a Japanese Irish Setter. Lost eye in Vietnam (?). Big fan of relaxing on stair. 8/10 would pet https://t.co/BLDqew2Ijj

# %%
tweet_ids = df['tweet_id']

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# %%
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 666020888022790149
# Success
# 2: 666029285002620928
# Success
# 3: 666033412701032449
# Success
# 4: 666044226329800704
# Success
# 5: 666049248165822465
# Success
# 6: 666050758794694657
# Success
# 7: 666051853826850816
# Success
# 8: 666055525042405380
# Success
# 9: 666057090499244032
# Success
# 10: 666058600524156928
# Success
# 11: 666063827256086533
# Success
# 12: 666071193221509120
# Success
# 13: 666073100786774016
# Success
# 14: 666082916733198337
# Success
# 15: 666094000022159362
# Success
# 16: 666099513787052032
# Success
# 17: 666102155909144576
# Success
# 18: 666104133288665088
# Success
# 19: 666268910803644416
# Success
# 20: 666273097616637952
# Success
# 21: 666287406224695296
# Success
# 22: 666293911632134144
# Success
# 23: 666337882303524864
# Success
# 24: 666345417576210432
# Success
# 25: 666353288456101888
# Success
# 26: 666362758909284353
# Success
# 27: 666373753744588802
# Success
# 28: 666396247373291520
# Success
# 29: 666407126856765440
# ...

# %%
my_list_of_dicts = []
for each_json_tweet in tweet:
    my_list_of_dicts.append(each_json_tweet._json)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-f538ec8f70d5> in <module>
#       1 my_list_of_dicts = []
# ----> 2 for each_json_tweet in tweet:
#       3     my_list_of_dicts.append(each_json_tweet._json)
#
# TypeError: 'Status' object is not iterable

# %%
all_data=[]
my_demo_list = []
for json_file in open('tweet_json.txt', encoding='utf-8'):  
    all_data.append(json.loads(json_file))

# %%
for each_dictionary in all_data:
        tweet_id = each_dictionary['id']
        text = each_dictionary['full_text']
        favorite_count = each_dictionary['favorite_count']
        retweet_count = each_dictionary['retweet_count']
        created_at = each_dictionary['created_at']
        my_demo_list.append({'tweet_id': str(tweet_id),
                             'text': str(text),
                             'favorite_count': int(favorite_count),
                             'retweet_count': int(retweet_count),
                             'created_at': created_at,
                            })
        #print(my_demo_list)
        tweet_json = pd.DataFrame(my_demo_list, columns = 
                                  ['tweet_id', 'text', 
                                   'favorite_count', 'retweet_count', 
                                   'created_at'])

# %%
tweet_json.head(2)
# Out:
#              tweet_id                                               text  \
# 0  666020888022790149  Here we have a Japanese Irish Setter. Lost eye...
# 1  666029285002620928  This is a western brown Mitsubishi terrier. Up...
#
#    favorite_count  retweet_count                      created_at
# 0            2388            458  Sun Nov 15 22:32:08 +0000 2015
# 1             120             42  Sun Nov 15 23:05:30 +0000 2015

# %%
img_prediction = df
img_prediction.head(2)
# Out:
# 0            tweet_id                                          jpg_url  \
# 1  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 2  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
#
# 0 img_num                      p1   p1_conf p1_dog                  p2  \
# 1       1  Welsh_springer_spaniel  0.465074   True              collie
# 2       1                 redbone  0.506826   True  miniature_pinscher
#
# 0              p2_conf p2_dog                   p3    p3_conf p3_dog
# 1             0.156665   True    Shetland_sheepdog  0.0614285   True
# 2  0.07419169999999999   True  Rhodesian_ridgeback    0.07201   True

# %%
twitter_data = pd.read_csv('./twitter-archive-enhanced.csv')
twitter_data.head(2)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# ...

# %%
twitter_data['dog_type']= twitter_data["doggo"]+twitter_data["floofer"]+twitter_data["pupper"]+twitter_data["puppo"]
twitter_data['dog_type'] = twitter_data.dog_type.str.replace("None","")
twitter_data.drop(columns = ["doggo","floofer","pupper","puppo"])
twitter_data[twitter_data["dog_type"]!=""].head(3)
# Out:
#               tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 9   890240255349198849                    NaN                  NaN
# 12  889665388333682689                    NaN                  NaN
# 14  889531135344209921                    NaN                  NaN
#
#                     timestamp  \
# 9   2017-07-26 15:59:51 +0000
# 12  2017-07-25 01:55:32 +0000
# 14  2017-07-24 17:02:04 +0000
#
#                                                source  \
# 9   <a href="http://twitter.com/download/iphone" r...
# 12  <a href="http://twitter.com/download/iphone" r...
# 14  <a href="http://twitter.com/download/iphone" r...
#
#                                                  text  retweeted_status_id  \
# 9   This is Cassie. She is a college pup. Studying...                  NaN
# 12  Here's a puppo that seems to be on the fence a...                  NaN
# 14  This is Stuart. He's sporting his favorite fan...                  NaN
#
# ...

# %%
twitter_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 18 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
twitter_data.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
twitter_data.isnull()
# Out:
#       tweet_id  in_reply_to_status_id  in_reply_to_user_id  timestamp  source  \
# 0        False                   True                 True      False   False
# 1        False                   True                 True      False   False
# 2        False                   True                 True      False   False
# 3        False                   True                 True      False   False
# 4        False                   True                 True      False   False
# ...        ...                    ...                  ...        ...     ...
# 2351     False                   True                 True      False   False
# 2352     False                   True                 True      False   False
# 2353     False                   True                 True      False   False
# 2354     False                   True                 True      False   False
# 2355     False                   True                 True      False   False
#
# ...

# %%
twitter_data.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
twitter_data[twitter_data.retweeted_status_id.notnull()].head(2)
# Out:
#               tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19  888202515573088257                    NaN                  NaN
# 32  886054160059072513                    NaN                  NaN
#
#                     timestamp  \
# 19  2017-07-21 01:02:36 +0000
# 32  2017-07-15 02:45:48 +0000
#
#                                                source  \
# 19  <a href="http://twitter.com/download/iphone" r...
# 32  <a href="http://twitter.com/download/iphone" r...
#
#                                                  text  retweeted_status_id  \
# 19  RT @dog_rates: This is Canela. She attempted s...         8.874740e+17
# 32  RT @Athletics: 12/10 #BATP https://t.co/WxwJmv...         8.860537e+17
#
#     retweeted_status_user_id retweeted_status_timestamp  \
# 19              4.196984e+09  2017-07-19 00:47:34 +0000
# 32              1.960740e+07  2017-07-15 02:44:07 +0000
#
#                                         expanded_urls  rating_numerator  \
# ...

# %%
twitter_data[twitter_data.retweeted_status_id.notnull()].head(2)
# Out:
#               tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19  888202515573088257                    NaN                  NaN
# 32  886054160059072513                    NaN                  NaN
#
#                     timestamp  \
# 19  2017-07-21 01:02:36 +0000
# 32  2017-07-15 02:45:48 +0000
#
#                                                source  \
# 19  <a href="http://twitter.com/download/iphone" r...
# 32  <a href="http://twitter.com/download/iphone" r...
#
#                                                  text  retweeted_status_id  \
# 19  RT @dog_rates: This is Canela. She attempted s...         8.874740e+17
# 32  RT @Athletics: 12/10 #BATP https://t.co/WxwJmv...         8.860537e+17
#
#     retweeted_status_user_id retweeted_status_timestamp  \
# 19              4.196984e+09  2017-07-19 00:47:34 +0000
# 32              1.960740e+07  2017-07-15 02:44:07 +0000
#
#                                         expanded_urls  rating_numerator  \
# ...

# %%
# Drop Retweets
twitter_data_clean = twitter_data[~twitter_data.text.str.startswith("RT @")]
twitter_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 18 columns):
# tweet_id                      2175 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2175 non-null object
# source                        2175 non-null object
# text                          2175 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2117 non-null object
# rating_numerator              2175 non-null int64
# rating_denominator            2175 non-null int64
# name                          2175 non-null object
# doggo                         2175 non-null object
# floofer                       2175 non-null object
# pupper                        2175 non-null object
# ...

# %%
#Remove replied to the tweets
twitter_data_clean = twitter_data_clean[~twitter_data_clean.in_reply_to_status_id.notnull()]
twitter_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 18 columns):
# tweet_id                      2097 non-null int64
# in_reply_to_status_id         0 non-null float64
# in_reply_to_user_id           0 non-null float64
# timestamp                     2097 non-null object
# source                        2097 non-null object
# text                          2097 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2094 non-null object
# rating_numerator              2097 non-null int64
# rating_denominator            2097 non-null int64
# name                          2097 non-null object
# doggo                         2097 non-null object
# floofer                       2097 non-null object
# pupper                        2097 non-null object
# puppo                         2097 non-null object
# ...

# %%
twitter_data_clean = twitter_data_clean[['tweet_id','timestamp','text','expanded_urls','rating_numerator','rating_denominator','name','dog_type']]
twitter_data_clean.head(2)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
#
#    rating_denominator     name dog_type
# 0                  10  Phineas
# 1                  10    Tilly

# %%
#Remove data where ratina Denom is not equal to 10 (which doesn't make sense as the ratinf standard id out of 10.
twitter_data_clean = twitter_data_clean[twitter_data_clean["rating_denominator"]==10]
twitter_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2080 entries, 0 to 2355
# Data columns (total 8 columns):
# tweet_id              2080 non-null int64
# timestamp             2080 non-null object
# text                  2080 non-null object
# expanded_urls         2077 non-null object
# rating_numerator      2080 non-null int64
# rating_denominator    2080 non-null int64
# name                  2080 non-null object
# dog_type              2080 non-null object
# dtypes: int64(3), object(5)
# memory usage: 146.2+ KB

# %%
#For now Remove data where ratina Numerator is huge (which motlikely is due to a decimal point)
twitter_data_clean = twitter_data_clean[twitter_data_clean["rating_numerator"]<=15]

# %%
twitter_data_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# ...

# %%
tweet_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 5 columns):
# tweet_id          2059 non-null object
# text              2059 non-null object
# favorite_count    2059 non-null int64
# retweet_count     2059 non-null int64
# created_at        2059 non-null object
# dtypes: int64(2), object(3)
# memory usage: 80.6+ KB

# %%
#change ID format to join it with Twitter_data
tweet_json.tweet_id = tweet_json.tweet_id.astype(np.int64)

# %%
#Merge twitter_data_clean and tweet_json to get the Favorite count & Retweet Count added. 
#Did a left join to keep those records in Twitter Data even if there was no info retrieved for some of the Twitter IDs from Twitter API

twitter_data_clean = pd.merge(twitter_data_clean, tweet_json[['tweet_id','retweet_count','favorite_count']],on=['tweet_id'], how='left')

# %%
twitter_data_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# ...

# %%
img_prediction.head(5)
# Out:
# 0            tweet_id                                          jpg_url  \
# 1  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 2  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 3  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 4  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 5  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
# 0 img_num                      p1   p1_conf p1_dog                  p2  \
# 1       1  Welsh_springer_spaniel  0.465074   True              collie
# 2       1                 redbone  0.506826   True  miniature_pinscher
# 3       1         German_shepherd  0.596461   True            malinois
# 4       1     Rhodesian_ridgeback  0.408143   True             redbone
# 5       1      miniature_pinscher  0.560311   True          Rottweiler
#
# 0              p2_conf p2_dog                   p3              p3_conf p3_dog
# ...

# %%
img_prediction_clean_melt1 = pd.melt(img_prediction, id_vars=['tweet_id', 'jpg_url', 'img_num'],
                           value_vars=['p1','p2','p3'], var_name='prediction', value_name='pred_val')

img_prediction_clean_melt2 = pd.melt(img_prediction, id_vars=['tweet_id', 'jpg_url', 'img_num'],
                           value_vars=['p1_conf','p2_conf','p3_conf'], var_name='prediction', value_name='pred_conf')

img_prediction_clean_melt2.prediction = img_prediction_clean_melt2.prediction.str[:2]
img_prediction_clean_melt3 = pd.melt(img_prediction, id_vars=['tweet_id', 'jpg_url', 'img_num'],
                           value_vars=['p1_dog','p3_dog','p3_dog'], var_name='prediction', value_name='pred_accuracy')

img_prediction_clean_melt3.prediction = img_prediction_clean_melt3.prediction.str[:2]

# %%
img_prediction_clean_melt = img_prediction_clean_melt1.merge(img_prediction_clean_melt2,on=['tweet_id','img_num','jpg_url','prediction'])
img_prediction_clean_melt = img_prediction_clean_melt.merge(img_prediction_clean_melt3,on=['tweet_id','img_num','jpg_url','prediction'])

# %%
img_prediction_clean_melt.head(5)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#   img_num prediction                pred_val pred_conf pred_accuracy
# 0       1         p1  Welsh_springer_spaniel  0.465074          True
# 1       1         p1                 redbone  0.506826          True
# 2       1         p1         German_shepherd  0.596461          True
# 3       1         p1     Rhodesian_ridgeback  0.408143          True
# 4       1         p1      miniature_pinscher  0.560311          True

# %%
#Removing wrong/False prediction (e.g. in one instance "paper Towel" was predicted as a dog breed.)
img_prediction_clean_melt = img_prediction_clean_melt[img_prediction_clean_melt.pred_accuracy=='True']
img_prediction_clean_melt.shape
# Out:
# (4530, 7)

# %%
#Remove duplicate records
img_prediction_clean_melt = img_prediction_clean_melt.drop_duplicates()
img_prediction_clean_melt.shape
# Out:
# (1638, 4)

# %%
grouped = img_prediction_clean_melt.groupby(['tweet_id', 'jpg_url', 'img_num','prediction']).sum().reset_index()
grouped_sorted = grouped.sort_values('pred_conf', ascending=False)

img_prediction_clean_melted = grouped_sorted.groupby(['tweet_id', 'jpg_url', 'img_num']).first().reset_index()
img_prediction_clean_melted.shape
# Out:
# (1638, 7)

# %%
img_prediction_clean_melted.head(2)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
#
#   img_num prediction                pred_val pred_conf pred_accuracy
# 0       1         p1  Welsh_springer_spaniel  0.465074          True
# 1       1         p1                 redbone  0.506826          True

# %%
twitter_data_clean.head(2)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
#
#    rating_denominator     name dog_type  retweet_count  favorite_count
# 0                  10  Phineas                  7596.0         35858.0
# 1                  10    Tilly                  5626.0         30933.0
